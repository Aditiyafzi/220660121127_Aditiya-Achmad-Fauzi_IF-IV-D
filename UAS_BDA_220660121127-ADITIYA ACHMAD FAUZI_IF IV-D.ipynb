# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Data transaksi
data = {
    'Power Bank': [1, 1, 1, 0, 1],
    'Case Ponsel': [1, 0, 1, 1, 1],
    'Tempered Glass': [0, 1, 1, 0, 0],
    'Tripod': [1, 0, 1, 1, 1],
    'Headset': [0, 1, 1, 1, 1]
}

df = pd.DataFrame(data)

# Menghasilkan frequent itemsets
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

# Menghasilkan aturan asosiasi
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Menampilkan hasil
print(frequent_itemsets)
print(rules)
# Out:
#     support                                    itemsets
# 0       0.8                                (Power Bank)
# 1       0.8                               (Case Ponsel)
# 2       0.4                            (Tempered Glass)
# 3       0.8                                    (Tripod)
# 4       0.8                                   (Headset)
# 5       0.6                   (Case Ponsel, Power Bank)
# 6       0.4                (Power Bank, Tempered Glass)
# 7       0.6                        (Tripod, Power Bank)
# 8       0.6                       (Headset, Power Bank)
# 9       0.8                       (Case Ponsel, Tripod)
# 10      0.6                      (Case Ponsel, Headset)
# 11      0.4                   (Headset, Tempered Glass)
# 12      0.6                           (Tripod, Headset)
# 13      0.6           (Case Ponsel, Tripod, Power Bank)
# 14      0.4          (Case Ponsel, Headset, Power Bank)
# 15      0.4       (Headset, Power Bank, Tempered Glass)
# 16      0.4               (Headset, Tripod, Power Bank)
# 17      0.6              (Case Ponsel, Tripod, Headset)
# 18      0.4  (Case Ponsel, Headset, Tripod, Power Bank)
#                            antecedents                         consequents  \
# 0                         (Power Bank)                    (Tempered Glass)
# 1                     (Tempered Glass)                        (Power Bank)
# 2                        (Case Ponsel)                            (Tripod)
# 3                             (Tripod)                       (Case Ponsel)
# 4                            (Headset)                    (Tempered Glass)
# 5                     (Tempered Glass)                           (Headset)
# 6            (Case Ponsel, Power Bank)                            (Tripod)
# 7                 (Tripod, Power Bank)                       (Case Ponsel)
# 8                        (Case Ponsel)                (Tripod, Power Bank)
# 9                             (Tripod)           (Case Ponsel, Power Bank)
# 10               (Headset, Power Bank)                    (Tempered Glass)
# 11           (Headset, Tempered Glass)                        (Power Bank)
# 12        (Power Bank, Tempered Glass)                           (Headset)
# 13                           (Headset)        (Power Bank, Tempered Glass)
# 14                        (Power Bank)           (Headset, Tempered Glass)
# 15                    (Tempered Glass)               (Headset, Power Bank)
# 16              (Case Ponsel, Headset)                            (Tripod)
# 17                   (Tripod, Headset)                       (Case Ponsel)
# 18                       (Case Ponsel)                   (Tripod, Headset)
# 19                            (Tripod)              (Case Ponsel, Headset)
# 20  (Case Ponsel, Headset, Power Bank)                            (Tripod)
# 21       (Tripod, Headset, Power Bank)                       (Case Ponsel)
# 22              (Case Ponsel, Headset)                (Tripod, Power Bank)
# 23           (Case Ponsel, Power Bank)                   (Tripod, Headset)
# 24                   (Tripod, Headset)           (Case Ponsel, Power Bank)
# 25                (Tripod, Power Bank)              (Case Ponsel, Headset)
# 26                       (Case Ponsel)       (Tripod, Headset, Power Bank)
# 27                            (Tripod)  (Case Ponsel, Headset, Power Bank)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                  0.8                 0.4      0.4    0.500000  1.250000
# 1                  0.4                 0.8      0.4    1.000000  1.250000
# 2                  0.8                 0.8      0.8    1.000000  1.250000
# 3                  0.8                 0.8      0.8    1.000000  1.250000
# 4                  0.8                 0.4      0.4    0.500000  1.250000
# 5                  0.4                 0.8      0.4    1.000000  1.250000
# 6                  0.6                 0.8      0.6    1.000000  1.250000
# 7                  0.6                 0.8      0.6    1.000000  1.250000
# 8                  0.8                 0.6      0.6    0.750000  1.250000
# 9                  0.8                 0.6      0.6    0.750000  1.250000
# 10                 0.6                 0.4      0.4    0.666667  1.666667
# 11                 0.4                 0.8      0.4    1.000000  1.250000
# 12                 0.4                 0.8      0.4    1.000000  1.250000
# 13                 0.8                 0.4      0.4    0.500000  1.250000
# 14                 0.8                 0.4      0.4    0.500000  1.250000
# 15                 0.4                 0.6      0.4    1.000000  1.666667
# 16                 0.6                 0.8      0.6    1.000000  1.250000
# 17                 0.6                 0.8      0.6    1.000000  1.250000
# 18                 0.8                 0.6      0.6    0.750000  1.250000
# 19                 0.8                 0.6      0.6    0.750000  1.250000
# 20                 0.4                 0.8      0.4    1.000000  1.250000
# 21                 0.4                 0.8      0.4    1.000000  1.250000
# 22                 0.6                 0.6      0.4    0.666667  1.111111
# 23                 0.6                 0.6      0.4    0.666667  1.111111
# 24                 0.6                 0.6      0.4    0.666667  1.111111
# 25                 0.6                 0.6      0.4    0.666667  1.111111
# 26                 0.8                 0.4      0.4    0.500000  1.250000
# 27                 0.8                 0.4      0.4    0.500000  1.250000
#
#     leverage  conviction  zhangs_metric
# 0       0.08         1.2       1.000000
# 1       0.08         inf       0.333333
# 2       0.16         inf       1.000000
# 3       0.16         inf       1.000000
# 4       0.08         1.2       1.000000
# 5       0.08         inf       0.333333
# 6       0.12         inf       0.500000
# 7       0.12         inf       0.500000
# 8       0.12         1.6       1.000000
# 9       0.12         1.6       1.000000
# 10      0.16         1.8       1.000000
# 11      0.08         inf       0.333333
# 12      0.08         inf       0.333333
# 13      0.08         1.2       1.000000
# 14      0.08         1.2       1.000000
# 15      0.16         inf       0.666667
# 16      0.12         inf       0.500000
# 17      0.12         inf       0.500000
# 18      0.12         1.6       1.000000
# 19      0.12         1.6       1.000000
# 20      0.08         inf       0.333333
# 21      0.08         inf       0.333333
# 22      0.04         1.2       0.250000
# 23      0.04         1.2       0.250000
# 24      0.04         1.2       0.250000
# 25      0.04         1.2       0.250000
# 26      0.08         1.2       1.000000
# 27      0.08         1.2       1.000000
# C:\Users\Lenovo\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
